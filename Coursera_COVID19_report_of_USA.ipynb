# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayanabh-K/Ayanabh-K/blob/master/Coursera_COVID19_report_of_USA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv")

# %%
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
df.describe()
# Out:
#                fips         cases         deaths
# count  61942.000000  6.194200e+04   61942.000000
# mean      32.247958  8.898301e+05   11779.067499
# std       18.788383  1.470231e+06   17345.774849
# min        1.000000  1.000000e+00       0.000000
# 25%       17.000000  7.078350e+04    1171.000000
# 50%       31.000000  3.514960e+05    5035.000000
# 75%       46.000000  1.043231e+06   14912.000000
# max       78.000000  1.216916e+07  104277.000000

# %%
df.shape
# Out:
# (61942, 5)

# %%
sns.scatterplot(x="cases", y="deaths", hue="deaths", size="deaths", data = df)
# Out:
# <Axes: xlabel='cases', ylabel='deaths'>

# %%
master_df = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv")
master_df['date'] = pd.to_datetime(master_df['date'])
master_df = master_df.set_index('date')
print(f"columns: {master_df.columns}")
master_df.index
# Out:
# columns: Index(['state', 'fips', 'cases', 'deaths'], dtype='object')
# DatetimeIndex(['2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-24', '2020-01-25', '2020-01-25', '2020-01-25',
#                '2020-01-26', '2020-01-26',
#                ...
#                '2023-03-23', '2023-03-23', '2023-03-23', '2023-03-23',
#                '2023-03-23', '2023-03-23', '2023-03-23', '2023-03-23',
#                '2023-03-23', '2023-03-23'],
#               dtype='datetime64[ns]', name='date', length=61942, freq=None)

# %% [markdown]
# Date time choosen 3 years back when it COVID as it's peak

# %%
from datetime import date, timedelta
today = date.today()
daybefore = today - timedelta(days = 365*3)
print(f"Today {today}")
print(f"Two days ago {daybefore}")
# Out:
# Today 2024-11-09
# Two days ago 2021-11-10

# %%
df.loc[daybefore:today].head()
# Out:
#                      state  fips    cases  deaths
# date
# 2021-11-10         Alabama     1   837428   15917
# 2021-11-10          Alaska     2   143345     811
# 2021-11-10  American Samoa    60        4       0
# 2021-11-10         Arizona     4  1199277   21525
# 2021-11-10        Arkansas     5   517675    8525

# %%
sns.kdeplot(df.loc[daybefore:today]['deaths'], fill = True)
# Out:
# <Axes: xlabel='deaths', ylabel='Density'>

# %%
current_df = df.loc[daybefore:today].sort_values(by = ['deaths', 'cases'], ascending = False)
current_df
# Out:
#                      state  fips     cases  deaths
# date
# 2023-03-23      California     6  12169158  104277
# 2023-03-22      California     6  12155467  104196
# 2023-03-21      California     6  12154941  104185
# 2023-03-20      California     6  12154293  104165
# 2023-03-19      California     6  12153083  104130
# ...                    ...   ...       ...     ...
# 2021-11-11  American Samoa    60         4       0
# 2021-11-12  American Samoa    60         4       0
# 2021-11-13  American Samoa    60         4       0
# 2021-11-14  American Samoa    60         4       0
# 2021-11-15  American Samoa    60         4       0
#
# [27944 rows x 4 columns]
